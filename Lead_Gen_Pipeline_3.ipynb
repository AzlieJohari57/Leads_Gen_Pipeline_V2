# %% [markdown]
# # Facebook & Website Mining (Silver 2)

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
from Apify_Scrapper_Functions import Get_Phone_Number_From_Facebook, Get_Phone_Number_From_Website

# %% [markdown]
# ### Import scrapped data

# %%
Scrapped_Data = pd.read_parquet("./Staging/Silver/Silver_data_1.parquet", engine="fastparquet")

# Check if UEN is unique
print(Scrapped_Data["UEN"].is_unique)
print(Scrapped_Data.shape)
# Out:
# True
# (100, 16)

# %% [markdown]
# ### Generate PIC Source Column

# %%
Scrapped_Data["PIC Source 1"] = None
Scrapped_Data["PIC Source 2"] = None
Scrapped_Data["PIC Source 3"] = None
Scrapped_Data = Scrapped_Data[["UEN","Phones", "Emails", "Website", "Facebook", "LinkedIn", "Instagram",  "TikTok", "operational_street", "operational_unit", "operational_postal_code", "operational_address", "PIC Source 1", "PIC Source 2", "PIC Source 3"]]

Scrapped_Data
# Out:
#            UEN         Phones              Emails  \
# 0    52895287X  [+6564836187]                None
# 1    53414661M           None                None
# 2   201505039Z  [+6562211336]  [sup@wantonsg.com]
# 3    53399916B           None                None
# 4   202429107W           None                None
# ..         ...            ...                 ...
# 95  T06LL0510H           None                None
# 96  202011894W  [+6591679396]                None
# 97   53478000L           None                None
# 98  201205374H           None                None
# 99   53463060W  [+6582368031]                None
#
#                                               Website  \
# 0   https://hungrygowhere.com/singapore/chng_li_ch...
# 1                 https://catzpatisserie.cococart.co/
# 2                               https://wantonsg.com/
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96  https://www.mycareersfuture.gov.sg/job/admin/o...
# 97                             https://chickenpie.sg/
# 98                                               None
# 99                                               None
#
#                                       Facebook LinkedIn  \
# 0                                         None     None
# 1   [https://www.facebook.com/CaTzPatisserie/]     None
# 2        [https://www.facebook.com/wanton.sg/]     None
# 3                                         None     None
# 4                                         None     None
# ..                                         ...      ...
# 95                                        None     None
# 96                                        None     None
# 97                                        None     None
# 98                                        None     None
# 99                                        None     None
#
#                                        Instagram TikTok  \
# 0                                           None   None
# 1    [https://www.instagram.com/catzpatisserie/]   None
# 2   [https://www.instagram.com/wanton.sg/?hl=en]   None
# 3                                           None   None
# 4                                           None   None
# ..                                           ...    ...
# 95                                          None   None
# 96                                          None   None
# 97                                          None   None
# 98                                          None   None
# 99                                          None   None
#
#                                   operational_street operational_unit  \
# 0     10 ANG MO KIO INDUSTRIAL PARK 2A AMK AUTOPOINT            01-21
# 1                    25 PHOENIX RISE HUA MEI GARDENS             None
# 2                               458 RACE COURSE ROAD             None
# 3                    200 JALAN SULTAN TEXTILE CENTRE            02-04
# 4                                 348 JALAN BOON LAY           01-07B
# ..                                               ...              ...
# 95           510 UPPER SERANGOON ROAD SUNSHINE LODGE            04-04
# 96       5 PEREIRA ROAD ASIAWIDE INDUSTRIAL BUILDING            04-01
# 97  21 COMPASSVALE STREET COMPASSVALE PRIMARY SCHOOL             None
# 98              101 KITCHENER ROAD JALAN BESAR PLAZA            02-05
# 99          4 DEFU LANE 10 01 DEFU INDUSTRIAL ESTATE             None
#
#    operational_postal_code                                operational_address  \
# 0                   568047  10 ANG MO KIO INDUSTRIAL PARK 2A AMK AUTOPOINT...
# 1                   668227   25 PHOENIX RISE HUA MEI GARDENS Singapore 668227
# 2                   218699              458 RACE COURSE ROAD Singapore 218699
# 3                   199018  200 JALAN SULTAN TEXTILE CENTRE 02-04 Singapor...
# 4                   619529         348 JALAN BOON LAY 01-07B Singapore 619529
# ..                     ...                                                ...
# 95                  534530  510 UPPER SERANGOON ROAD SUNSHINE LODGE 04-04 ...
# 96                  368025  5 PEREIRA ROAD ASIAWIDE INDUSTRIAL BUILDING 04...
# 97                  545091  21 COMPASSVALE STREET COMPASSVALE PRIMARY SCHO...
# 98                  208511  101 KITCHENER ROAD JALAN BESAR PLAZA 02-05 Sin...
# 99                  539185  4 DEFU LANE 10 01 DEFU INDUSTRIAL ESTATE Singa...
#
#    PIC Source 1 PIC Source 2 PIC Source 3
# 0          None         None         None
# 1          None         None         None
# 2          None         None         None
# 3          None         None         None
# 4          None         None         None
# ..          ...          ...          ...
# 95         None         None         None
# 96         None         None         None
# 97         None         None         None
# 98         None         None         None
# 99         None         None         None
#
# [100 rows x 15 columns]

# %% [markdown]
# ### Insert PIC 1 Source that has phone number with RecordOwl

# %%
# Assign PIC Source 1 as "RecordOwl" if Phones has any value
Scrapped_Data.loc[Scrapped_Data["Phones"].notna(), "PIC Source 1"] = "RecordOwl"
Scrapped_Data
# Out:
#            UEN         Phones              Emails  \
# 0    52895287X  [+6564836187]                None
# 1    53414661M           None                None
# 2   201505039Z  [+6562211336]  [sup@wantonsg.com]
# 3    53399916B           None                None
# 4   202429107W           None                None
# ..         ...            ...                 ...
# 95  T06LL0510H           None                None
# 96  202011894W  [+6591679396]                None
# 97   53478000L           None                None
# 98  201205374H           None                None
# 99   53463060W  [+6582368031]                None
#
#                                               Website  \
# 0   https://hungrygowhere.com/singapore/chng_li_ch...
# 1                 https://catzpatisserie.cococart.co/
# 2                               https://wantonsg.com/
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96  https://www.mycareersfuture.gov.sg/job/admin/o...
# 97                             https://chickenpie.sg/
# 98                                               None
# 99                                               None
#
#                                       Facebook LinkedIn  \
# 0                                         None     None
# 1   [https://www.facebook.com/CaTzPatisserie/]     None
# 2        [https://www.facebook.com/wanton.sg/]     None
# 3                                         None     None
# 4                                         None     None
# ..                                         ...      ...
# 95                                        None     None
# 96                                        None     None
# 97                                        None     None
# 98                                        None     None
# 99                                        None     None
#
#                                        Instagram TikTok  \
# 0                                           None   None
# 1    [https://www.instagram.com/catzpatisserie/]   None
# 2   [https://www.instagram.com/wanton.sg/?hl=en]   None
# 3                                           None   None
# 4                                           None   None
# ..                                           ...    ...
# 95                                          None   None
# 96                                          None   None
# 97                                          None   None
# 98                                          None   None
# 99                                          None   None
#
#                                   operational_street operational_unit  \
# 0     10 ANG MO KIO INDUSTRIAL PARK 2A AMK AUTOPOINT            01-21
# 1                    25 PHOENIX RISE HUA MEI GARDENS             None
# 2                               458 RACE COURSE ROAD             None
# 3                    200 JALAN SULTAN TEXTILE CENTRE            02-04
# 4                                 348 JALAN BOON LAY           01-07B
# ..                                               ...              ...
# 95           510 UPPER SERANGOON ROAD SUNSHINE LODGE            04-04
# 96       5 PEREIRA ROAD ASIAWIDE INDUSTRIAL BUILDING            04-01
# 97  21 COMPASSVALE STREET COMPASSVALE PRIMARY SCHOOL             None
# 98              101 KITCHENER ROAD JALAN BESAR PLAZA            02-05
# 99          4 DEFU LANE 10 01 DEFU INDUSTRIAL ESTATE             None
#
#    operational_postal_code                                operational_address  \
# 0                   568047  10 ANG MO KIO INDUSTRIAL PARK 2A AMK AUTOPOINT...
# 1                   668227   25 PHOENIX RISE HUA MEI GARDENS Singapore 668227
# 2                   218699              458 RACE COURSE ROAD Singapore 218699
# 3                   199018  200 JALAN SULTAN TEXTILE CENTRE 02-04 Singapor...
# 4                   619529         348 JALAN BOON LAY 01-07B Singapore 619529
# ..                     ...                                                ...
# 95                  534530  510 UPPER SERANGOON ROAD SUNSHINE LODGE 04-04 ...
# 96                  368025  5 PEREIRA ROAD ASIAWIDE INDUSTRIAL BUILDING 04...
# 97                  545091  21 COMPASSVALE STREET COMPASSVALE PRIMARY SCHO...
# 98                  208511  101 KITCHENER ROAD JALAN BESAR PLAZA 02-05 Sin...
# 99                  539185  4 DEFU LANE 10 01 DEFU INDUSTRIAL ESTATE Singa...
#
#    PIC Source 1 PIC Source 2 PIC Source 3
# 0     RecordOwl         None         None
# 1          None         None         None
# 2     RecordOwl         None         None
# 3          None         None         None
# 4          None         None         None
# ..          ...          ...          ...
# 95         None         None         None
# 96    RecordOwl         None         None
# 97         None         None         None
# 98         None         None         None
# 99    RecordOwl         None         None
#
# [100 rows x 15 columns]

# %% [markdown]
# ### Separate W/O Phone Numbers

# %%
# Separate rows with and without phone numbers
df_with_phones = Scrapped_Data[Scrapped_Data["Phones"].notna()]
df_without_phones = Scrapped_Data[Scrapped_Data["Phones"].isna()]

# Store unique phone numbers inside With_Phones_1
df_With_Phones_1 = df_with_phones[df_with_phones["Phones"].duplicated(keep=False) == False]

# Store duplicate phone numbers inside refilter_df_1
df_Duplicate_Phones_1 = df_with_phones[df_with_phones["Phones"].duplicated(keep=False) == True]

# Print shapes
print("Total having Phone numbers:", df_with_phones.shape)
print("Total without Phone numbers:", df_without_phones.shape)
print("Unique phone rows (df_With_Phones_1):", df_With_Phones_1.shape)
print("Duplicate phone rows (df_Duplicate_Phones_1):", df_Duplicate_Phones_1.shape)
# Out:
# Total having Phone numbers: (39, 15)
# Total without Phone numbers: (61, 15)
# Unique phone rows (df_With_Phones_1): (37, 15)
# Duplicate phone rows (df_Duplicate_Phones_1): (2, 15)

# %% [markdown]
# ### Merge df_without_phones with df_Duplicate_Phones_1

# %%
df_without_phones_and_Duplicates = (
    pd.concat([df_Duplicate_Phones_1, df_without_phones], ignore_index=True)
      .drop_duplicates(subset=["UEN"])
)

df_without_phones_and_Duplicates.shape
# Out:
# (63, 15)

# %%
### Final W/O Phones 

print(df_With_Phones_1.shape)
print(df_without_phones_and_Duplicates.shape)

print(df_With_Phones_1["UEN"].is_unique)
print(df_without_phones_and_Duplicates["UEN"].is_unique)

df_without_phones_and_Duplicates["PIC Source 1"] = None
# Out:
# (37, 15)
# (63, 15)
# True
# True

# %% [markdown]
# ### Separate W/O Facebook from df_without_phones_and_Duplicates

# %%
# DataFrame with Facebook (not null and not empty)
df_with_facebook = df_without_phones_and_Duplicates[
    df_without_phones_and_Duplicates["Facebook"].notna() &
    (df_without_phones_and_Duplicates["Facebook"] != "")
]

# DataFrame without Facebook (null or empty)
df_without_facebook = df_without_phones_and_Duplicates[
    df_without_phones_and_Duplicates["Facebook"].isna() |
    (df_without_phones_and_Duplicates["Facebook"] == "")
]

# Check the shapes
print(f"With Facebook: {df_with_facebook.shape}")
print(f"Without Facebook: {df_without_facebook.shape}")
# Out:
# With Facebook: (9, 15)
# Without Facebook: (54, 15)

# %%
print(df_with_facebook["UEN"].is_unique)
# Out:
# True

# %%
df_with_facebook.shape
# Out:
# (9, 15)

# %% [markdown]
# ### Extract Phone Number of Facebook Pages

# %%
facebook_phone_df, facebook_no_phone_df = Get_Phone_Number_From_Facebook(df_with_facebook)
# Out:
# Valid Facebook URLs: 9, Filtered out (profiles/invalid): 0
# Processing 9 Facebook pages...
# Batch 1/1...
#   Original URLs: 9, Unique URLs: 9
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> Status: RUNNING, Message:
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:01.001Z ACTOR: Pulling container image of build VRed9P5z8GOu5TP7V from registry.
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:01.006Z ACTOR: Creating container.
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:01.066Z ACTOR: Starting container.
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:01.067Z ACTOR: Running under "LIMITED_PERMISSIONS" permission level.
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:02.033Z INFO  System info {"apifyVersion":"3.5.1","apifyClientVersion":"2.19.0","crawleeVersion":"3.15.2","osType":"Linux","nodeVersion":"v20.19.6"}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:02.749Z INFO  Results Limit undefined
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:02.789Z INFO  CheerioCrawler: Using the old RequestQueue implementation without request locking.
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> Status: RUNNING, Message: Starting the crawler.
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:03.299Z INFO  CheerioCrawler: Starting the crawler.
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:06.335Z INFO  Decoded ID S:_I100057052035034:930772625501130:930772625501130 from UzpfSTEwMDA1NzA1MjAzNTAzNDo5MzA3NzI2MjU1MDExMzA6OTMwNzcyNjI1NTAxMTMw for https://m.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:06.362Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. BLOCKED
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:06.363Z     at handlePageDetails (file:///usr/src/app/dist/src/src-facebook-pages/routes.js:75:19) {"id":"PPyyUrqQQtOMJCi","url":"https://www.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz","retryCount":1}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:08.649Z INFO  [PROGRESS]: Found 1 new page_contact_information, 1 for URL https://www.facebook.com/Bedok85/
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:10.900Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Detected a session error, rotating session...
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:10.902Z The proxy server rejected the request with status code 595 (ECONNRESET)
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:10.904Z
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:10.905Z  {"id":"XQktTuunuLWBRij","url":"https://www.facebook.com/CaTzPatisserie/","retryCount":1}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:11.104Z INFO  [PROGRESS]: Found 1 new page_contact_information, 1 for URL https://www.facebook.com/funtoast
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:11.221Z INFO  [PROGRESS]: Found 1 new page_contact_information, 1 for URL https://www.facebook.com/jiaksongsg/
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:13.766Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Page access was blocked or page is not available, retrying with new session
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> Status: RUNNING, Message: Crawled 5/9 pages, 0 failed requests, desired concurrency 10.
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:13.767Z     at handleFacebookObject (file:///usr/src/app/dist/src/validate-urls-scraper/routes.js:86:15) {"id":"PPyyUrqQQtOMJCi","url":"https://www.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz","retryCount":2}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:27.520Z INFO  [PROGRESS]: Found 1 new page_contact_information, 1 for URL https://www.facebook.com/CaTzPatisserie/
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:30.117Z INFO  Decoded ID S:_I100057052035034:930772625501130:930772625501130 from UzpfSTEwMDA1NzA1MjAzNTAzNDo5MzA3NzI2MjU1MDExMzA6OTMwNzcyNjI1NTAxMTMw for https://m.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:30.324Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. BLOCKED
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:30.325Z     at handlePageDetails (file:///usr/src/app/dist/src/src-facebook-pages/routes.js:75:19) {"id":"PPyyUrqQQtOMJCi","url":"https://www.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz","retryCount":3}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> Status: RUNNING, Message: Crawled 6/9 pages, 0 failed requests, desired concurrency 10.
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:33.351Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. request timed out after 30 seconds. {"id":"rKfNRodqbxwcboV","url":"https://www.facebook.com/ahmalormee/","retryCount":1}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:35.749Z INFO  Decoded ID S:_I100057052035034:930772625501130:930772625501130 from UzpfSTEwMDA1NzA1MjAzNTAzNDo5MzA3NzI2MjU1MDExMzA6OTMwNzcyNjI1NTAxMTMw for https://m.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:35.839Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. BLOCKED
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:35.840Z     at handlePageDetails (file:///usr/src/app/dist/src/src-facebook-pages/routes.js:75:19) {"id":"PPyyUrqQQtOMJCi","url":"https://www.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz","retryCount":4}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:37.548Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Page access was blocked or page is not available, retrying with new session
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:37.550Z     at handleFacebookObject (file:///usr/src/app/dist/src/validate-urls-scraper/routes.js:86:15) {"id":"rKfNRodqbxwcboV","url":"https://www.facebook.com/ahmalormee/","retryCount":2}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:40.984Z INFO  Decoded ID S:_I100057052035034:930772625501130:930772625501130 from UzpfSTEwMDA1NzA1MjAzNTAzNDo5MzA3NzI2MjU1MDExMzA6OTMwNzcyNjI1NTAxMTMw for https://m.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:41.027Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. BLOCKED
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:41.029Z     at handlePageDetails (file:///usr/src/app/dist/src/src-facebook-pages/routes.js:75:19) {"id":"PPyyUrqQQtOMJCi","url":"https://www.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz","retryCount":5}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> Status: RUNNING, Message: Crawled 7/9 pages, 0 failed requests, desired concurrency 10.
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:39:47.137Z INFO  [PROGRESS]: Found 1 new page_contact_information, 1 for URL https://www.facebook.com/ahmalormee/
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:03.299Z INFO  CheerioCrawler:Statistics: CheerioCrawler request statistics: {"requestAvgFailedDurationMillis":null,"requestAvgFinishedDurationMillis":6360,"requestsFinishedPerMinute":7,"requestsFailedPerMinute":0,"requestTotalDurationMillis":44521,"requestsTotal":7,"crawlerRuntimeMillis":60511,"retryHistogram":[5,1,1]}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:03.303Z INFO  CheerioCrawler:AutoscaledPool: state {"currentConcurrency":2,"desiredConcurrency":10,"systemStatus":{"isSystemIdle":true,"memInfo":{"isOverloaded":false,"limitRatio":0.2,"actualRatio":0},"eventLoopInfo":{"isOverloaded":false,"limitRatio":0.7,"actualRatio":0},"cpuInfo":{"isOverloaded":false,"limitRatio":0.4,"actualRatio":0},"clientInfo":{"isOverloaded":false,"limitRatio":0.3,"actualRatio":0}}}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:05.037Z INFO  Attempt 1 failed for https://www.facebook.com/v16.0/plugins/page.php?adapt_container_width=true&app_id=113869198637480&container_width=500&hide_cover=false&href=https%3A%2F%2Fwww.facebook.com%2Fharuplate&locale=en_US&sdk=joey&show_facepile=true&small_header=false&hide_cta=true&tabs=timeline
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:07.816Z INFO  [PROGRESS]: Found 1 new page_contact_information, 1 for URL https://www.facebook.com/haruplate
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:08.232Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. The proxy server rejected the request with status code 590 (UPSTREAM503)
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> Status: RUNNING, Message: Crawled 8/9 pages, 0 failed requests, desired concurrency 10.
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:08.233Z  {"id":"PPyyUrqQQtOMJCi","url":"https://www.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz","retryCount":6}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:14.070Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. Page access was blocked or page is not available, retrying with new session
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:14.071Z     at handleFacebookObject (file:///usr/src/app/dist/src/validate-urls-scraper/routes.js:86:15) {"id":"PPyyUrqQQtOMJCi","url":"https://www.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz","retryCount":7}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:19.816Z INFO  Decoded ID S:_I100057052035034:930772625501130:930772625501130 from UzpfSTEwMDA1NzA1MjAzNTAzNDo5MzA3NzI2MjU1MDExMzA6OTMwNzcyNjI1NTAxMTMw for https://m.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:20.017Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. BLOCKED
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:20.019Z     at handlePageDetails (file:///usr/src/app/dist/src/src-facebook-pages/routes.js:75:19) {"id":"PPyyUrqQQtOMJCi","url":"https://www.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz","retryCount":8}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:25.443Z INFO  Decoded ID S:_I100057052035034:930772625501130:930772625501130 from UzpfSTEwMDA1NzA1MjAzNTAzNDo5MzA3NzI2MjU1MDExMzA6OTMwNzcyNjI1NTAxMTMw for https://m.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:25.538Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. BLOCKED
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:25.540Z     at handlePageDetails (file:///usr/src/app/dist/src/src-facebook-pages/routes.js:75:19) {"id":"PPyyUrqQQtOMJCi","url":"https://www.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz","retryCount":9}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:31.927Z INFO  Decoded ID S:_I100057052035034:930772625501130:930772625501130 from UzpfSTEwMDA1NzA1MjAzNTAzNDo5MzA3NzI2MjU1MDExMzA6OTMwNzcyNjI1NTAxMTMw for https://m.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:31.954Z WARN  CheerioCrawler: Reclaiming failed request back to the list or queue. BLOCKED
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:31.956Z     at handlePageDetails (file:///usr/src/app/dist/src/src-facebook-pages/routes.js:75:19) {"id":"PPyyUrqQQtOMJCi","url":"https://www.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz","retryCount":10}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:38.998Z INFO  Decoded ID S:_I100057052035034:930772625501130:930772625501130 from UzpfSTEwMDA1NzA1MjAzNTAzNDo5MzA3NzI2MjU1MDExMzA6OTMwNzcyNjI1NTAxMTMw for https://m.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:39.139Z ERROR CheerioCrawler: Request failed and reached maximum retries. Error: BLOCKED
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:39.141Z     at handlePageDetails (file:///usr/src/app/dist/src/src-facebook-pages/routes.js:75:19)
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:39.142Z     at resolveFacebookEntityByUrl (file:///usr/src/app/dist/src/validate-urls-scraper/routes.js:465:38)
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:39.144Z     at process.processTicksAndRejections (node:internal/process/task_queues:95:5)
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:39.145Z     at async file:///usr/src/app/dist/src/validate-urls-scraper/main.js:29:30
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:39.147Z     at async wrap (/usr/src/app/node_modules/@apify/timeout/cjs/index.cjs:54:21) {"id":"PPyyUrqQQtOMJCi","url":"https://www.facebook.com/story.php?story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl&id=100057052035034&mibextid=Nif5oz","method":"GET","uniqueKey":"https://m.facebook.com/story.php?id=100057052035034&mibextid=Nif5oz&story_fbid=pfbid0MR7E9PKrYarVRmRAPLAoRvMDScbknJv3eK1AsJdtfkgMzmJdGEJQftRFATVJYWapl"}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:39.266Z INFO  CheerioCrawler: All requests from the queue have been processed, the crawler will shut down.
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:39.346Z INFO  CheerioCrawler: Final request statistics: {"requestsFinished":8,"requestsFailed":1,"retryHistogram":[6,1,1,null,null,null,null,null,null,null,1],"requestAvgFailedDurationMillis":3184,"requestAvgFinishedDurationMillis":13653,"requestsFinishedPerMinute":5,"requestsFailedPerMinute":0,"requestTotalDurationMillis":112410,"requestsTotal":9,"crawlerRuntimeMillis":96557}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:39.347Z INFO  CheerioCrawler: Error analysis: {"totalErrors":1,"uniqueErrors":1,"mostCommonErrors":["1x: BLOCKED (file:///usr/src/app/dist/src/src-facebook-pages/routes.js:75:19)"]}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:39.349Z INFO  CheerioCrawler: Finished! Total 9 requests: 8 succeeded, 1 failed. {"terminal":true}
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> 2026-01-27T07:40:39.406Z INFO  *** DONE ***
# [apify.facebook-page-contact-information runId:v495A8zZBIw8xARuV] -> Status: SUCCEEDED, Message: Finished! Total 9 requests: 8 succeeded, 1 failed.
#   Retrieved 9 results from Apify
#   Sample item keys: ['url', 'error', 'errorDescription']
#   DEBUG: URL https://www.facebook.com/ahmalormee/... | raw_phone=None
#   DEBUG: URL https://www.facebook.com/CaTzPatisserie/... | raw_phone=None
#   DEBUG: URL https://www.facebook.com/funtoast... | raw_phone=+65 6816 2849
#   DEBUG: URL https://www.facebook.com/Bedok85/... | raw_phone=None
#   DEBUG: URL https://www.facebook.com/jiaksongsg/... | raw_phone=None
#   DEBUG: URL https://m.facebook.com/lianhuatfishsoup/... | raw_phone=None
#   DEBUG: URL https://www.facebook.com/haruplate... | raw_phone=None
#   DEBUG: URL https://m.facebook.com/100076205071703... | raw_phone=None
# Done! Found 1/9 phone numbers.
# Summary: 1 with phones, 8 without phones (includes 0 filtered URLs)

# %%
print("with fb")
print("----------------")
print(facebook_phone_df["Phones"].apply(str).is_unique)
print(facebook_phone_df["UEN"].is_unique)
print(facebook_phone_df.shape)

print("/n without fb")
print("----------------")
print(facebook_no_phone_df["Phones"].apply(str).is_unique)
print(facebook_no_phone_df["UEN"].is_unique)
print(facebook_no_phone_df.shape)
# Out:
# with fb
# ----------------
# True
# True
# (1, 15)
# /n without fb
# ----------------
# False
# True
# (8, 15)

# %% [markdown]
# ### Adding Source to facebook_phone_df and merging with df_With_Phones_1

# %%
facebook_phone_df.shape
# Out:
# (1, 15)

# %% [markdown]
# ### Assign PIC 1 SOurce as Facebook

# %%
# Assign PIC Source 1 as "RecordOwl" if Phones has any value
facebook_phone_df.loc[facebook_phone_df["Phones"].notna(), "PIC Source 1"] = "Facebook"

# %% [markdown]
# ###

# %% [markdown]
# ### Merge df_With_Phones_1 with facebook_phone_df = with unique value phone number

# %%
df_With_Phones_2 = pd.concat([df_With_Phones_1, facebook_phone_df], ignore_index=True)


print(df_With_Phones_2["UEN"].is_unique)
print(df_With_Phones_2.shape)
# Out:
# True
# (38, 15)

# %% [markdown]
# ### Merging back facebook_no_phone_df with df_without_facebook = no valid number

# %%
df_without_phones_2 = pd.concat([df_without_facebook, facebook_no_phone_df], ignore_index=True)

print(df_without_phones_2["UEN"].is_unique)
print(df_without_phones_2.shape)
# Out:
# True
# (62, 15)

# %% [markdown]
# ### Quality Check df_With_Phones_2

# %%
# Check for NA or empty values in Phones and PIC Source 1
print("Phones - NA count:", df_With_Phones_2["Phones"].isna().sum())
print("Phones - Empty string count:", (df_With_Phones_2["Phones"] == "").sum())
print("PIC Source 1 - NA count:", df_With_Phones_2["PIC Source 1"].isna().sum())
print("PIC Source 1 - Empty string count:", (df_With_Phones_2["PIC Source 1"] == "").sum())
# Out:
# Phones - NA count: 0
# Phones - Empty string count: 0
# PIC Source 1 - NA count: 0
# PIC Source 1 - Empty string count: 0

# %% [markdown]
# ### Quality Check df_without_phones_2

# %%
# Check where PIC Source 1 is not NA in df_without_phones_2
print("Rows where PIC Source 1 is not NA:")
print(df_without_phones_2[df_without_phones_2["PIC Source 1"].notna()].shape)
print()
df_without_phones_2[df_without_phones_2["PIC Source 1"].notna()]
# Out:
# Rows where PIC Source 1 is not NA:
# (0, 15)
# Empty DataFrame
# Columns: [UEN, Phones, Emails, Website, Facebook, LinkedIn, Instagram, TikTok, operational_street, operational_unit, operational_postal_code, operational_address, PIC Source 1, PIC Source 2, PIC Source 3]
# Index: []

# %% [markdown]
# ### Separate W/O Websites

# %%
# DataFrame with Websites (not null and not empty)
df_with_websites = df_without_phones_2[
    df_without_phones_2["Website"].notna() &
    (df_without_phones_2["Website"] != "")
]

# DataFrame without Websites (null or empty)
df_without_websites = df_without_phones_2[
    df_without_phones_2["Website"].isna() |
    (df_without_phones_2["Website"] == "")
]

# Check the shapes
print(f"With Websites: {df_with_websites.shape}")
print(f"Without Websites: {df_without_websites.shape}")
print(f"Total from df_without_phones_2: {df_without_phones_2.shape}")
# Out:
# With Websites: (10, 15)
# Without Websites: (52, 15)
# Total from df_without_phones_2: (62, 15)

# %% [markdown]
# ### Extract Phone Numbers from Websites

# %%
from Apify_Scrapper_Functions import Get_Phone_Number_From_Facebook, Get_Phone_Number_From_Website

scrapped_from_websites = Get_Phone_Number_From_Website(df_with_websites)
# Out:
# ======================================================================
# 🌐 WEBSITE PHONE NUMBER SCRAPER - COST-OPTIMIZED
# ======================================================================
# 📊 Configuration:
#    • Batch size: 500 websites (increased for efficiency)
#    • Concurrency: 3 browsers (parallel processing)
#    • Page timeout: 15s (reduced for speed)
#    • Function timeout: 30s (optimized)
#    • Retries: 1 (minimize compute waste)
#    • Browser: Chromium (lightweight)
#    • Proxy: DATACENTER (cost-optimized)
#    • Strategy: Contact page → Homepage fallback
# ======================================================================
#
# 🔑 Validating Apify API token...
# ✅ API Key valid - User: epos-pte-ltd
#    • Plan: SCALE
#    • Credits remaining: Check your dashboard at https://console.apify.com/billing
#
# 📋 Total rows in RecordOwl_Leads: 10
# 📋 Rows with valid websites: 10
#
# ======================================================================
# 🔍 STEP 1: VERIFYING WEBSITE ACCESSIBILITY
# ======================================================================
# Testing HTTP/HTTPS connectivity for all websites...
#   ✅ https://www.myfood.sg/
#   ⏭️  https://www.mycareersfuture.gov.sg/job/food-and-beverage/general-manager-sv-services-engineering-8ee823de39cbc5a13ba01da9eea8b197 - Skipped (contains 'mycareersfuture')
#   ⏭️  https://www.mycareersfuture.gov.sg/job/food-and-beverage/assistant-cook-zhou-jia-48c4b20b7e2de91e21b00c542c387774 - Skipped (contains 'mycareersfuture')
#   ⏭️  https://www.mycareersfuture.gov.sg/job/food-and-beverage/fb-supervisor-lit-joyfood-c7f123001c6d50601735b821648fb53a - Skipped (contains 'mycareersfuture')
#   ✅ https://www.dynastygroup.com.sg/bowlngrill
#   ✅ https://www.joohwafood.com.sg/
#   ✅ https://chickenpie.sg/
#   ✅ https://misstamchiak.com/ah-ma-lor-mee
#   ✅ https://catzpatisserie.cococart.co/
#   ✅ https://haruplate.com/
#
# 📊 Verification Summary:
#    • Verified (accessible): 7
#    • Failed (inaccessible): 0
#    • Skipped (blocked keywords): 3
#
# ✅ Proceeding to scrape 7 verified websites
# ======================================================================
#
# ======================================================================
# 🌐 STEP 2: SCRAPING VERIFIED WEBSITES
# ======================================================================
#
# ──────────────────────────────────────────────────────────────────────
# 📦 Batch 1/1 - Processing 7 verified websites
#   📋 Processing 7 websites in single actor run
#   🚀 Launching Apify actor with 3 concurrent browsers...
#   ❌ Error during scraping: ApifyApiError: Input is not valid: You currently do not have access to proxy groups: DATACENTER
#   ❌ Batch error: Error during scraping: ApifyApiError: Input is not valid: You currently do not have access to proxy groups: DATACENTER
#
# ======================================================================
# ✅ PROCESSING COMPLETE
# ======================================================================
# 📊 Final Statistics:
#    • Total rows: 10
#    • Websites verified accessible: 7
#    • Websites skipped (keywords): 3
#    • Websites scraped: 7
#    • Phones found: 0
# ======================================================================

# %%
scrapped_from_websites_copy = scrapped_from_websites.drop_duplicates(subset=["UEN"], keep="first")

# Mask for rows with valid phone values (not NA, not None, not empty string)
mask_has_phone = (
    scrapped_from_websites_copy["Phones"].notna() & 
    (scrapped_from_websites_copy["Phones"].apply(str) != "None") & 
    (scrapped_from_websites_copy["Phones"].apply(str) != "")
)

website_number = scrapped_from_websites_copy[mask_has_phone].copy()
no_website_number = scrapped_from_websites_copy[~mask_has_phone].copy()

# %%
# Assign PIC Source 1 as "RecordOwl" if Phones has any value
website_number.loc[website_number["Phones"].notna(), "PIC Source 1"] = "Website"

# %%
scrapped_from_websites_copy.shape
# Out:
# (10, 20)

# %%
website_number.shape
# Out:
# (0, 20)

# %%
no_website_number.shape
# Out:
# (10, 20)

# %% [markdown]
# ### Merge df_With_Phones_2 with website_number

# %%
df_With_Phones_2.shape
# Out:
# (38, 15)

# %%
website_number.shape
# Out:
# (0, 20)

# %%
df_With_Phones_3 = pd.concat([df_With_Phones_2, website_number], ignore_index=True)

print(df_With_Phones_3["UEN"].is_unique)
print(df_With_Phones_3.shape)
# Out:
# True
# (38, 20)

# %% [markdown]
# ### Merge df_without_websites with no_website_number

# %%
df_without_websites.shape
# Out:
# (52, 15)

# %%
no_website_number.shape
# Out:
# (10, 20)

# %%
df_without_phones_3 = pd.concat([df_without_websites, no_website_number], ignore_index=True)

print(df_without_phones_3["UEN"].is_unique)
print(df_without_phones_3.shape)
# Out:
# True
# (62, 20)

# %% [markdown]
# ### Quality Check df_With_Phones_3

# %%
# Check for NA or empty values in Phones and PIC Source 1
print("Phones - NA count:", df_With_Phones_3["Phones"].isna().sum())
print("Phones - Empty string count:", (df_With_Phones_3["Phones"] == "").sum())
print("PIC Source 1 - NA count:", df_With_Phones_3["PIC Source 1"].isna().sum())
print("PIC Source 1 - Empty string count:", (df_With_Phones_3["PIC Source 1"] == "").sum())
# Out:
# Phones - NA count: 0
# Phones - Empty string count: 0
# PIC Source 1 - NA count: 0
# PIC Source 1 - Empty string count: 0

# %%
df_With_Phones_3["UEN"].is_unique
# Out:
# True

# %% [markdown]
# ### Quality Check df_without_phones_3

# %%
# Check for NA or empty values in Phones and PIC Source 1
print("Phones - NA count:", df_without_phones_3["Phones"].isna().sum())
print("Phones - Empty string count:", (df_without_phones_3["Phones"] == "").sum())
print("PIC Source 1 - NA count:", df_without_phones_3["PIC Source 1"].isna().sum())
print("PIC Source 1 - Empty string count:", (df_without_phones_3["PIC Source 1"] == "").sum())
# Out:
# Phones - NA count: 61
# Phones - Empty string count: 0
# PIC Source 1 - NA count: 62
# PIC Source 1 - Empty string count: 0

# %%
df_without_phones_3["UEN"].is_unique
# Out:
# True

# %%
df_With_Phones_3
# Out:
#            UEN         Phones                       Emails  \
# 0    52895287X  [+6564836187]                         None
# 1   201505039Z  [+6562211336]           [sup@wantonsg.com]
# 2   201212824G  [+6562550155]                         None
# 3   201334572W  [+6596882525]        [8082fnbpl@gmail.com]
# 4   201621449E  [+6562659515]                         None
# 5   201818844M  [+6585288528]    [phovietnam.sg@gmail.com]
# 6    53383118X  [+6580705986]                         None
# 7   T17LL0782C  [+6587801998]                         None
# 8   202007378D  [+6568072250]                         None
# 9   202346258K  [+6596963939]                         None
# 10  201902852K  [+6590234137]                         None
# 11  201533054M  [+6581395952]  [hello@wildfireburgers.com]
# 12  201431834G  [+6567443022]                         None
# 13   53200683J  [+6592287073]                         None
# 14   48609500B  [+6562228202]                         None
# 15   53387333M  [+6568722236]                         None
# 16   53291761L  [+6582366396]                         None
# 17  201540883E  [+6565357777]                         None
# 18  202323972G  [+6563968926]                         None
# 19   53468768K  [+6587924161]                         None
# 20  202235279H  [+6564248787]                         None
# 21  201621437K  [+6563868081]                         None
# 22   53169707W  [+6590097762]                         None
# 23   53292316B  [+6568288885]                         None
# 24  202315944E  [+6563861816]                         None
# 25  201601248H  [+6594567976]                         None
# 26   53084879A  [+6596906606]                         None
# 27  201309437N  [+6562968368]          [sales@aeris.group]
# 28   53265100J  [+6562275892]                         None
# 29   53479115L  [+6598644724]                         None
# 30  201815072D  [+6581369961]                         None
# 31   53457383E  [+6598658891]                         None
# 32  201312040R  [+6567482436]                         None
# 33  200402181M  [+6563342628]                         None
# 34  200207535E  [+6562859078]                         None
# 35  202011894W  [+6591679396]                         None
# 36   53463060W  [+6582368031]                         None
# 37  202103738H    +6568162849                         None
#
#                                               Website  \
# 0   https://hungrygowhere.com/singapore/chng_li_ch...
# 1                               https://wantonsg.com/
# 2                                                None
# 3                                                None
# 4                              https://kimlygroup.sg/
# 5                              https://phovietnam.sg/
# 6                                                None
# 7                                                None
# 8   https://www.mycareersfuture.gov.sg/job/food-an...
# 9                                                None
# 10                              http://www.quench.sg/
# 11  https://www.straitstimes.com/life/food/food-pi...
# 12  https://www.mycareersfuture.gov.sg/job/food-an...
# 13                                               None
# 14                                               None
# 15                                               None
# 16                   https://thefragrancekitchen.com/
# 17                           https://www.ey.com/en_sg
# 18                                               None
# 19                        https://newpalanivilas.com/
# 20                                    https://zf.com/
# 21                                               None
# 22                                               None
# 23  https://parkhotelgroup.com/en/alexandra/aqua-luna
# 24  https://www.mycareersfuture.gov.sg/job/food-an...
# 25                                               None
# 26        https://misstamchiak.com/sean-kee-duck-rice
# 27                              https://aeris.com.sg/
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32  https://www.mycareersfuture.gov.sg/job/others/...
# 33                       https://pumproomasia.com.sg/
# 34                                               None
# 35  https://www.mycareersfuture.gov.sg/job/admin/o...
# 36                                               None
# 37                           https://funtoast.com.sg/
#
#                                              Facebook  \
# 0                                                None
# 1               [https://www.facebook.com/wanton.sg/]
# 2                                                None
# 3        [https://m.facebook.com/8082KOPITIAM/about/]
# 4                                                None
# 5           [https://www.facebook.com/phovietnam.sg/]
# 6   [https://www.facebook.com/sinkeefamouschickenr...
# 7                                                None
# 8                                                None
# 9            [https://www.facebook.com/RITZSKITCHEN/]
# 10                [https://www.facebook.com/quenchsg]
# 11      [https://www.facebook.com/wildfireburgers.sg]
# 12                                               None
# 13  [https://www.facebook.com/share.php?u=https%3a...
# 14                                               None
# 15                                               None
# 16                                               None
# 17      [https://www.facebook.com/EYCareersSingapore]
# 18                                               None
# 19         [https://www.facebook.com/newpalanivilas/]
# 20          [https://www.facebook.com/zfgroup.global]
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26            [https://www.facebook.com/misstamchiak]
# 27                                               None
# 28                                               None
# 29                                               None
# 30  [https://www.facebook.com/aljilanicuisines/alb...
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                  https://www.facebook.com/funtoast
#
#                                              LinkedIn  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17         [https://www.linkedin.com/in/namsoonliew/]
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27  [https://sg.linkedin.com/company/aeris-dynamic...
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
#
#                                             Instagram TikTok  \
# 0                                                None   None
# 1        [https://www.instagram.com/wanton.sg/?hl=en]   None
# 2                                                None   None
# 3   [https://www.instagram.com/explore/locations/5...   None
# 4                                                None   None
# 5                                                None   None
# 6                                                None   None
# 7     [https://www.instagram.com/sg.jinhojiak/?hl=en]   None
# 8                                                None   None
# 9                                                None   None
# 10              [https://www.instagram.com/qu3nchsg/]   None
# 11     [https://www.instagram.com/wildfireburgers.sg]   None
# 12                                               None   None
# 13                                               None   None
# 14                                               None   None
# 15                                               None   None
# 16              [https://www.instagram.com/instatfk/]   None
# 17                                               None   None
# 18           [https://www.instagram.com/sgpbusiness/]   None
# 19                                               None   None
# 20                                               None   None
# 21                                               None   None
# 22                                               None   None
# 23  [https://www.instagram.com/momentusatalexandra...   None
# 24        [https://www.instagram.com/piztasingapore/]   None
# 25                                               None   None
# 26  [https://www.instagram.com/misstamchiak/, http...   None
# 27                                               None   None
# 28                                               None   None
# 29                                               None   None
# 30                                               None   None
# 31                                               None   None
# 32                                               None   None
# 33                                               None   None
# 34                                               None   None
# 35                                               None   None
# 36                                               None   None
# 37            [https://www.instagram.com/funtoastsg/]   None
#
#                                    operational_street operational_unit  \
# 0      10 ANG MO KIO INDUSTRIAL PARK 2A AMK AUTOPOINT            01-21
# 1                                458 RACE COURSE ROAD             None
# 2                            1 SOPHIA ROAD ONE SOPHIA            01-52
# 3       21 BENOI SECTOR MAPLETREE BENOI LOGISTICS HUB            01-05
# 4                                  13, WOODLANDS LINK             None
# 5                                161B PUNGGOL CENTRAL            18-97
# 6                                    14 MEDICAL DRIVE            01-03
# 7              71 NANYANG DRIVE NTU INNOVATION CENTRE            03-23
# 8            51 UBI AVENUE 1 PAYA UBI INDUSTRIAL PARK            01-17
# 9          713 JURONG WEST STREET 71 NANYANG SAPPHIRE            B1-37
# 10      43A PUAY HEE AVENUE SINDO INDUSTRIAL BUILDING            00-00
# 11                     11 UNITY STREET ROBERTSON WALK            01-33
# 12                                  271, GEYLANG ROAD             None
# 13                            326 WOODLANDS STREET 32           01-103
# 14                 335 SMITH STREET CHINATOWN COMPLEX           02-119
# 15                              110 PASIR RIS CENTRAL            02-11
# 16                                 109 TECK WHYE LANE           06-572
# 17  21 Tan Quee Lan Street Heritage Place Virtual ...            02-04
# 18         929 TAMPINES STREET 91 TAMPINES PALMSPRING           01-451
# 19  27 WOODLANDS INDUSTRIAL PARK E1 HIANGKIE INDUS...            01-04
# 20                845 YISHUN STREET 81 KHATIB CENTRAL           02-186
# 21               681 HOUGANG AVENUE 8 HOUGANG VILLAGE           02-801
# 22  51 OLD AIRPORT ROAD OLD AIRPORT ROAD HAWKERS' ...             None
# 23                                     ALEXANDRA ROAD             None
# 24           50 SERANGOON NORTH AVENUE 4 FIRST CENTRE            06-08
# 25                                  23 KIAN TECK ROAD            01-02
# 26                                   659 GEYLANG ROAD             None
# 27                  10 ANSON ROAD INTERNATIONAL PLAZA            01-76
# 28                            653 WOODLANDS RING ROAD           07-468
# 29                           418 BEDOK NORTH AVENUE 2            01-97
# 30                                 133 SIMEI STREET 1           02-150
# 31              1 WOODLANDS INDUSTRIAL PARK E2 NORDIX            01-10
# 32                              204 SERANGOON CENTRAL           01-104
# 33         22 THOMSON GREEN #01- THOMSON HILLS ESTATE            16-82
# 34                         67 UBI ROAD 1 OXLEY BIZHUB            06-06
# 35        5 PEREIRA ROAD ASIAWIDE INDUSTRIAL BUILDING            04-01
# 36           4 DEFU LANE 10 01 DEFU INDUSTRIAL ESTATE             None
# 37                                12 CASHEW ROAD ESPA            01-08
#
#    operational_postal_code                                operational_address  \
# 0                   568047  10 ANG MO KIO INDUSTRIAL PARK 2A AMK AUTOPOINT...
# 1                   218699              458 RACE COURSE ROAD Singapore 218699
# 2                   228149    1 SOPHIA ROAD ONE SOPHIA 01-52 Singapore 228149
# 3                   629853  21 BENOI SECTOR MAPLETREE BENOI LOGISTICS HUB ...
# 4                   738725                13, WOODLANDS LINK Singapore 738725
# 5                   822161        161B PUNGGOL CENTRAL 18-97 Singapore 822161
# 6                   117599            14 MEDICAL DRIVE 01-03 Singapore 117599
# 7                   638075  71 NANYANG DRIVE NTU INNOVATION CENTRE 03-23 S...
# 8                   408933  51 UBI AVENUE 1 PAYA UBI INDUSTRIAL PARK 01-17...
# 9                   640713  713 JURONG WEST STREET 71 NANYANG SAPPHIRE B1-...
# 10                  348186  43A PUAY HEE AVENUE SINDO INDUSTRIAL BUILDING ...
# 11                  237995  11 UNITY STREET ROBERTSON WALK 01-33 Singapore...
# 12                  389324                 271, GEYLANG ROAD Singapore 389324
# 13                  730326    326 WOODLANDS STREET 32 01-103 Singapore 730326
# 14                  050335  335 SMITH STREET CHINATOWN COMPLEX 02-119 Sing...
# 15                  519641       110 PASIR RIS CENTRAL 02-11 Singapore 519641
# 16                  680109         109 TECK WHYE LANE 06-572 Singapore 680109
# 17                  188108  21 Tan Quee Lan Street Heritage Place Virtual ...
# 18                  520929  929 TAMPINES STREET 91 TAMPINES PALMSPRING 01-...
# 19                  757718  27 WOODLANDS INDUSTRIAL PARK E1 HIANGKIE INDUS...
# 20                  760845  845 YISHUN STREET 81 KHATIB CENTRAL 02-186 Sin...
# 21                  530681  681 HOUGANG AVENUE 8 HOUGANG VILLAGE 02-801 Si...
# 22                  390051  51 OLD AIRPORT ROAD OLD AIRPORT ROAD HAWKERS' ...
# 23                  159972                    ALEXANDRA ROAD Singapore 159972
# 24                  555856  50 SERANGOON NORTH AVENUE 4 FIRST CENTRE 06-08...
# 25                  628774           23 KIAN TECK ROAD 01-02 Singapore 628774
# 26                  389589                  659 GEYLANG ROAD Singapore 389589
# 27                  079903  10 ANSON ROAD INTERNATIONAL PLAZA 01-76 Singap...
# 28                  730653    653 WOODLANDS RING ROAD 07-468 Singapore 730653
# 29                  460418    418 BEDOK NORTH AVENUE 2 01-97 Singapore 460418
# 30                  520133         133 SIMEI STREET 1 02-150 Singapore 520133
# 31                  757447  1 WOODLANDS INDUSTRIAL PARK E2 NORDIX 01-10 Si...
# 32                  550204      204 SERANGOON CENTRAL 01-104 Singapore 550204
# 33                  574898  22 THOMSON GREEN #01- THOMSON HILLS ESTATE 16-...
# 34                  408730  67 UBI ROAD 1 OXLEY BIZHUB 06-06 Singapore 408730
# 35                  368025  5 PEREIRA ROAD ASIAWIDE INDUSTRIAL BUILDING 04...
# 36                  539185  4 DEFU LANE 10 01 DEFU INDUSTRIAL ESTATE Singa...
# 37                  679693         12 CASHEW ROAD ESPA 01-08 Singapore 679693
#
#    PIC Source 1 PIC Source 2 PIC Source 3 Website_Scrape_Status  \
# 0     RecordOwl         None         None                   NaN
# 1     RecordOwl         None         None                   NaN
# 2     RecordOwl         None         None                   NaN
# 3     RecordOwl         None         None                   NaN
# 4     RecordOwl         None         None                   NaN
# 5     RecordOwl         None         None                   NaN
# 6     RecordOwl         None         None                   NaN
# 7     RecordOwl         None         None                   NaN
# 8     RecordOwl         None         None                   NaN
# 9     RecordOwl         None         None                   NaN
# 10    RecordOwl         None         None                   NaN
# 11    RecordOwl         None         None                   NaN
# 12    RecordOwl         None         None                   NaN
# 13    RecordOwl         None         None                   NaN
# 14    RecordOwl         None         None                   NaN
# 15    RecordOwl         None         None                   NaN
# 16    RecordOwl         None         None                   NaN
# 17    RecordOwl         None         None                   NaN
# 18    RecordOwl         None         None                   NaN
# 19    RecordOwl         None         None                   NaN
# 20    RecordOwl         None         None                   NaN
# 21    RecordOwl         None         None                   NaN
# 22    RecordOwl         None         None                   NaN
# 23    RecordOwl         None         None                   NaN
# 24    RecordOwl         None         None                   NaN
# 25    RecordOwl         None         None                   NaN
# 26    RecordOwl         None         None                   NaN
# 27    RecordOwl         None         None                   NaN
# 28    RecordOwl         None         None                   NaN
# 29    RecordOwl         None         None                   NaN
# 30    RecordOwl         None         None                   NaN
# 31    RecordOwl         None         None                   NaN
# 32    RecordOwl         None         None                   NaN
# 33    RecordOwl         None         None                   NaN
# 34    RecordOwl         None         None                   NaN
# 35    RecordOwl         None         None                   NaN
# 36    RecordOwl         None         None                   NaN
# 37     Facebook         None         None                   NaN
#
#    Website_Scrape_Error Website_Phones Website_Contact_Page Website_Page_Type
# 0                   NaN            NaN                  NaN               NaN
# 1                   NaN            NaN                  NaN               NaN
# 2                   NaN            NaN                  NaN               NaN
# 3                   NaN            NaN                  NaN               NaN
# 4                   NaN            NaN                  NaN               NaN
# 5                   NaN            NaN                  NaN               NaN
# 6                   NaN            NaN                  NaN               NaN
# 7                   NaN            NaN                  NaN               NaN
# 8                   NaN            NaN                  NaN               NaN
# 9                   NaN            NaN                  NaN               NaN
# 10                  NaN            NaN                  NaN               NaN
# 11                  NaN            NaN                  NaN               NaN
# 12                  NaN            NaN                  NaN               NaN
# 13                  NaN            NaN                  NaN               NaN
# 14                  NaN            NaN                  NaN               NaN
# 15                  NaN            NaN                  NaN               NaN
# 16                  NaN            NaN                  NaN               NaN
# 17                  NaN            NaN                  NaN               NaN
# 18                  NaN            NaN                  NaN               NaN
# 19                  NaN            NaN                  NaN               NaN
# 20                  NaN            NaN                  NaN               NaN
# 21                  NaN            NaN                  NaN               NaN
# 22                  NaN            NaN                  NaN               NaN
# 23                  NaN            NaN                  NaN               NaN
# 24                  NaN            NaN                  NaN               NaN
# 25                  NaN            NaN                  NaN               NaN
# 26                  NaN            NaN                  NaN               NaN
# 27                  NaN            NaN                  NaN               NaN
# 28                  NaN            NaN                  NaN               NaN
# 29                  NaN            NaN                  NaN               NaN
# 30                  NaN            NaN                  NaN               NaN
# 31                  NaN            NaN                  NaN               NaN
# 32                  NaN            NaN                  NaN               NaN
# 33                  NaN            NaN                  NaN               NaN
# 34                  NaN            NaN                  NaN               NaN
# 35                  NaN            NaN                  NaN               NaN
# 36                  NaN            NaN                  NaN               NaN
# 37                  NaN            NaN                  NaN               NaN

# %%
df_without_phones_3
# Out:
#            UEN         Phones                     Emails  \
# 0    53104036D  [+6561000029]  [yummeefoods@foodline.sg]
# 1    53399916B           None                       None
# 2   202429107W           None                       None
# 3   202135973C           None                       None
# 4   202540224W           None                       None
# ..         ...            ...                        ...
# 57  202417398C           None                       None
# 58   53478000L           None                       None
# 59  T16LL2399D           None   [ahmalormee@foodline.sg]
# 60   53414661M           None                       None
# 61  201902492D           None                       None
#
#                                    Website  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# ..                                     ...
# 57          https://www.joohwafood.com.sg/
# 58                  https://chickenpie.sg/
# 59  https://misstamchiak.com/ah-ma-lor-mee
# 60     https://catzpatisserie.cococart.co/
# 61                  https://haruplate.com/
#
#                                     Facebook LinkedIn  \
# 0                                       None     None
# 1                                       None     None
# 2                                       None     None
# 3                                       None     None
# 4                                       None     None
# ..                                       ...      ...
# 57                                      None     None
# 58                                      None     None
# 59      https://www.facebook.com/ahmalormee/     None
# 60  https://www.facebook.com/CaTzPatisserie/     None
# 61        https://www.facebook.com/haruplate     None
#
#                                             Instagram TikTok  \
# 0                                                None   None
# 1                                                None   None
# 2                                                None   None
# 3                                                None   None
# 4                                                None   None
# ..                                                ...    ...
# 57                                               None   None
# 58                                               None   None
# 59      [https://www.instagram.com/ahmalormee/?hl=en]   None
# 60        [https://www.instagram.com/catzpatisserie/]   None
# 61  [https://www.instagram.com/haruplate, https://...   None
#
#                                   operational_street operational_unit  \
# 0                                  3 YUNG SHENG ROAD           03-125
# 1                    200 JALAN SULTAN TEXTILE CENTRE            02-04
# 2                                 348 JALAN BOON LAY           01-07B
# 3        24A SENOKO SOUTH ROAD SELECT GROUP BUILDING             None
# 4          53 GEYLANG BAHRU GEYLANG BAHRU RIVERPOINT          06-3599
# ..                                               ...              ...
# 57                                  46 HOLLAND DRIVE           01-359
# 58  21 COMPASSVALE STREET COMPASSVALE PRIMARY SCHOOL             None
# 59                       427 BUKIT PANJANG RING ROAD           08-699
# 60                   25 PHOENIX RISE HUA MEI GARDENS             None
# 61              7 TEMASEK BOULEVARD SUNTEC TOWER ONE            12-07
#
#    operational_postal_code                                operational_address  \
# 0                   618499          3 YUNG SHENG ROAD 03-125 Singapore 618499
# 1                   199018  200 JALAN SULTAN TEXTILE CENTRE 02-04 Singapor...
# 2                   619529         348 JALAN BOON LAY 01-07B Singapore 619529
# 3                   758099  24A SENOKO SOUTH ROAD SELECT GROUP BUILDING Si...
# 4                   330053  53 GEYLANG BAHRU GEYLANG BAHRU RIVERPOINT 06-3...
# ..                     ...                                                ...
# 57                  270046           46 HOLLAND DRIVE 01-359 Singapore 270046
# 58                  545091  21 COMPASSVALE STREET COMPASSVALE PRIMARY SCHO...
# 59                  670427  427 BUKIT PANJANG RING ROAD 08-699 Singapore 6...
# 60                  668227   25 PHOENIX RISE HUA MEI GARDENS Singapore 668227
# 61                  038987  7 TEMASEK BOULEVARD SUNTEC TOWER ONE 12-07 Sin...
#
#    PIC Source 1 PIC Source 2 PIC Source 3 Website_Scrape_Status  \
# 0          None         None         None                   NaN
# 1          None         None         None                   NaN
# 2          None         None         None                   NaN
# 3          None         None         None                   NaN
# 4          None         None         None                   NaN
# ..          ...          ...          ...                   ...
# 57         None         None         None                 error
# 58         None         None         None                 error
# 59         None         None         None                 error
# 60         None         None         None                 error
# 61         None         None         None                 error
#
#                                  Website_Scrape_Error Website_Phones  \
# 0                                                 NaN            NaN
# 1                                                 NaN            NaN
# 2                                                 NaN            NaN
# 3                                                 NaN            NaN
# 4                                                 NaN            NaN
# ..                                                ...            ...
# 57  Error during scraping: ApifyApiError: Input is...           None
# 58  Error during scraping: ApifyApiError: Input is...           None
# 59  Error during scraping: ApifyApiError: Input is...           None
# 60  Error during scraping: ApifyApiError: Input is...           None
# 61  Error during scraping: ApifyApiError: Input is...           None
#
#    Website_Contact_Page Website_Page_Type
# 0                   NaN               NaN
# 1                   NaN               NaN
# 2                   NaN               NaN
# 3                   NaN               NaN
# 4                   NaN               NaN
# ..                  ...               ...
# 57                 None              None
# 58                 None              None
# 59                 None              None
# 60                 None              None
# 61                 None              None
#
# [62 rows x 20 columns]

# %% [markdown]
# ### Saving

# %%
df_With_Phones_3.to_parquet("./Staging/Silver/Silver_data_2_Phone.parquet", index=False, engine="fastparquet")

# %%
df_without_phones_3.to_parquet("./Staging/Silver/Silver_data_2_No_Phone.parquet", index=False, engine="fastparquet")
